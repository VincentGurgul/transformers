# %% [markdown]
# In this notebook, we will prepare the lyrics data downloaded from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/News+Aggregator).

# %% [markdown]
# _Credit: for the preparation of the news data, we took some of the code privided by this Towards Data Science [post](https://towardsdatascience.com/conditional-text-generation-by-fine-tuning-gpt-2-11c1a9fc639d)._

# %% [markdown]
# # Main Steps
# 1. Load in the datasets
# 3. Keep only the data that meets the following criteria:
#     - Business news (``CATEGORY``=='b')
#     - Random selection of 10k
# 4. Fetch the news content from the link in the dataset

# %%
import pandas as pd
from newspaper import Article

random_state = 1234

columns = ['ID',
           'TITLE',
           'URL',
           'PUBLISHER',
           'CATEGORY', #News category (b = business, t = science and technology, e = entertainment, m = health)
           'Alphanumeric ID',
           'HOSTNAME Url',
           'TIMESTAMP']

newsData = pd.read_csv("./raw_data/newsCorpora.csv",
                       delimiter = '	', names = columns)
print("Original news df shape: ", newsData.shape)

# keep only business news
newsData = newsData[newsData.CATEGORY == 'b']
print("Business news df shape: ", newsData.shape)
# print("Science and Technology news df shape", newsData.shape)

# due to calculation power limit, we only keep the randomly-selected 10k news
newsData = newsData.sample(10**4, random_state = random_state)
print("Randomly select 10k Business news df shape: ", newsData.shape)


newsData.head(3)
# Out:
# Original news df shape:  (422419, 8)
# Business news df shape:  (115967, 8)
# Randomly select 10k Business news df shape:  (10000, 8)
#             ID                                              TITLE  \
# 44056    44057  Missing Malayasia Airlines MH370: China sends ...
# 316897  317357  5 Things to Know About the Changing State of O...
# 367142  367602            ECB's Draghi's Plan May Miss the Target
#
#                                                       URL  \
# 44056   http://www.india.com/loudspeaker/missing-malay...
# 316897  http://blogs.wsj.com/briefly/2014/06/25/5-thin...
# 367142  http://www.marketpulse.com/20140706/ecbs-dragh...
#
#                            PUBLISHER CATEGORY                Alphanumeric ID  \
# 44056                      India.com        b  dpJ38zm8NY8hUFM22x2aL0hc9hjfM
# 316897  Wall Street Journal \(blog\)        b  doclsNbkIioH-9Maj9kRRSWSdRTuM
# 367142          MarketPulse \(blog\)        b  dybB1-1U7xt8vLMLKhbW1GpBlkggM
#
#                HOSTNAME Url      TIMESTAMP
# 44056         www.india.com  1395824966103
# 316897        blogs.wsj.com  1403775235740
# 367142  www.marketpulse.com  1404822872146

# %%
from tqdm.contrib import tzip
newsData['got_text'] = 0


newsData_1 = newsData.iloc[:3333]
newsData_2 = newsData.iloc[3333:6666]
newsData_3 = newsData.iloc[6666:]

# %%
for row, url in tzip(newsData_1.index, newsData_1.URL):
    url_new = 'https'+url[4:]
#     print(row, url)
    try:
        article = Article(url_new)
        article.download()
        article.parse()
        newsData_1.loc[row, 'text'] = article.text
        if article.text:
            newsData_1.loc[row, 'got_text'] = 1 
    except: pass
    
newsData_1
# Out:
#   0%|          | 0/3333 [00:00<?, ?it/s]
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname IST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
#             ID                                              TITLE  \
# 44056    44057  Missing Malayasia Airlines MH370: China sends ...
# 316897  317357  5 Things to Know About the Changing State of O...
# 367142  367602            ECB's Draghi's Plan May Miss the Target
# 24979    24980   Schneiderman: Fast stock trade advantages unfair
# 47630    47631  Candy Crush Saga shares dive 10% in Wall Stree...
# ...        ...                                                ...
# 348807  349267        HK currency intervention is a positive sign
# 356825  357285  Uber's London operations remain in legal limbo...
# 211834  212280                Call for end to anti-China protests
# 376762  377222                             July 15, 2014, 4:51 am
# 116050  116386               Nestle sees FX offset organic growth
#
#                                                       URL  \
# 44056   http://www.india.com/loudspeaker/missing-malay...
# 316897  http://blogs.wsj.com/briefly/2014/06/25/5-thin...
# 367142  http://www.marketpulse.com/20140706/ecbs-dragh...
# 24979   http://poststar.com/news/state-and-regional/sc...
# 47630   http://www.thisismoney.co.uk/money/markets/art...
# ...                                                   ...
# 348807  http://www.ig.com/uk/market-update/2014/07/03/...
# 356825  http://venturebeat.com/2014/07/03/ubers-london...
# 211834  http://www.belfasttelegraph.co.uk/news/world-n...
# 376762  https://au.news.yahoo.com/thewest/business/wor...
# 116050  http://www.just-food.com/news/nestle-sees-fx-o...
#
#                              PUBLISHER CATEGORY  \
# 44056                        India.com        b
# 316897    Wall Street Journal \(blog\)        b
# 367142            MarketPulse \(blog\)        b
# 24979            Glens Falls Post-Star        b
# 47630                    This is Money        b
# ...                                ...      ...
# 348807                              IG        b
# 356825                     VentureBeat        b
# 211834               Belfast Telegraph        b
# 376762             The West Australian        b
# 116050  just-food.com \(subscription\)        b
#
#                       Alphanumeric ID                HOSTNAME Url  \
# 44056   dpJ38zm8NY8hUFM22x2aL0hc9hjfM               www.india.com
# 316897  doclsNbkIioH-9Maj9kRRSWSdRTuM               blogs.wsj.com
# 367142  dybB1-1U7xt8vLMLKhbW1GpBlkggM         www.marketpulse.com
# 24979   d5fZSL3c7uQ95bMK38nkSLgMo0cAM                poststar.com
# 47630   dQtK6MP92Wshd3MbmOLp71BNJ1smM       www.thisismoney.co.uk
# ...                               ...                         ...
# 348807  dkpRSIMBCMKcw0MGAdthwBjOXNMEM                  www.ig.com
# 356825  deamRsxqjRde37Mkd7klW11hc6dcM             venturebeat.com
# 211834  dqs7XmgHyoVndfMqMxxv0Zk_zZgoM  www.belfasttelegraph.co.uk
# 376762  dDbZs5yNvMXdzyM2eLkppVUBnmu6M           au.news.yahoo.com
# 116050  dql5TDrSP1EyZEMWsEY47opbGWU7M           www.just-food.com
#
#             TIMESTAMP  got_text  \
# 44056   1395824966103         1
# 316897  1403775235740         0
# 367142  1404822872146         1
# 24979   1395320415890         0
# 47630   1395880982244         1
# ...               ...       ...
# 348807  1404381649556         1
# 356825  1404522180234         0
# 211834  1400373219633         1
# 376762  1405422893222         0
# 116050  1397574679867         1
#
#                                                      text
# 44056   Also Read - Australia: Memorial Planned Honour...
# 316897                                                NaN
# 367142  Mario Draghi’s plan to end the euro area’s len...
# 24979                                                 NaN
# 47630   Candy Crush Saga shares dive 10% in Wall Stree...
# ...                                                   ...
# 348807  Spread bets and CFDs are complex instruments a...
# 356825                                                NaN
# 211834  Mobs burned and looted scores of foreign-owned...
# 376762                                                NaN
# 116050  The US$4.5bn deal, agreed in August, is being ...
#
# [3333 rows x 10 columns]

# %%
for row, url in tzip(newsData_2.index, newsData_2.URL):
    url_new = 'https'+url[4:]
#     print(row, url)
    try:
        article = Article(url_new)
        article.download()
        article.parse()
        newsData_2.loc[row, 'text'] = article.text
        if article.text:
            newsData_2.loc[row, 'got_text'] = 1 
    except: pass
    
newsData_2
# Out:
#   0%|          | 0/3333 [00:00<?, ?it/s]
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname IST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
#             ID                                              TITLE  \
# 29430    29431          Gul at odds with Erdogan over Twitter ban
# 314477  314937  Hazard Insurers May Face Suit Over Fees to Fan...
# 204381  204817        Nissan profit rises as global sales pick up
# 171067  171403  UPDATE 2-EBay beefs up US war chest in pursuit...
# 24379    24380    Boeing 787's design, manufacture safe, FAA says
# ...        ...                                                ...
# 196412  196848  COLUMN-Was Barclays the problem, or was it the...
# 158868  159204              Amazon's Classic Take On The Classics
# 127632  127968  General Mills' New Privacy Policy Restricts Co...
# 296772  297232  SolarCity gets into photovoltaic manufacturing...
# 418336  418855  Jessica Alba's Honest Co. valued at almost $1 ...
#
#                                                       URL  \
# 29430   http://gulfnews.com/news/world/other-world/tur...
# 314477  http://www.bloomberg.com/news/2014-06-25/hazar...
# 204381  http://www.newsday.com/business/nissan-profit-...
# 171067  http://www.reuters.com/article/2014/04/29/ebay...
# 24379   http://www.tulsaworld.com/business/aerospace/b...
# ...                                                   ...
# 196412  http://www.reuters.com/article/2014/05/08/colu...
# 158868  http://blogs.wsj.com/moneybeat/2014/04/24/amaz...
# 127632  http://publicradioeast.org/post/general-mills-...
# 296772  http://www.bizjournals.com/sanjose/news/2014/0...
# 418336  http://www.azcentral.com/story/entertainment/p...
#
#                               PUBLISHER CATEGORY  \
# 29430                      gulfnews.com        b
# 314477                        Bloomberg        b
# 204381                          Newsday        b
# 171067                          Reuters        b
# 24379                       Tulsa World        b
# ...                                 ...      ...
# 196412                          Reuters        b
# 158868     Wall Street Journal \(blog\)        b
# 127632                Public Radio East        b
# 296772  Silicon Valley Business Journal        b
# 418336                        azcentral        b
#
#                       Alphanumeric ID         HOSTNAME Url      TIMESTAMP  \
# 29430   drWjpn6_UzSkmiM_9qWYJe3-LIGPM         gulfnews.com  1395504371448
# 314477  dYl0oLFTVhcqb7M89YQbLlPHc5HuM    www.bloomberg.com  1403701980981
# 204381  dz8V3qjYFB3qJkM-K5H53BVUMOfXM      www.newsday.com  1399911319557
# 171067  d4LdeQeG96e-2JMUeby0G-P-7w3hM      www.reuters.com  1398849377518
# 24379   dhpfyfVbJn2C9wMqhHh7BvZNhtmvM   www.tulsaworld.com  1395317048158
# ...                               ...                  ...            ...
# 196412  dmfYAYOSCXeIgdMeNy_RGzRlSo-4M      www.reuters.com  1399625744680
# 158868  dmQqhPNKBmqhwnMNnj-ERzfMdzl6M        blogs.wsj.com  1398393873190
# 127632  d-0bCW2yA_8Sq2MzCOcNrOt3VU-bM  publicradioeast.org  1397760846283
# 296772  dZmv_NETbjeVQ4MocN2FOaVtOyFLM  www.bizjournals.com  1403066474971
# 418336  d0f8zdyvksyB6zMEGb1w9OxBcQzUM    www.azcentral.com  1409200536026
#
#         got_text                                               text
# 29430          1  Istanbul: Turkish President Abdullah Gul set h...
# 314477         1  Why did this happen?\n\nPlease make sure your ...
# 204381         0                                                NaN
# 171067         0                                                NaN
# 24379          1  WASHINGTON — Boeing's design and manufacture ...
# ...          ...                                                ...
# 196412         0                                                NaN
# 158868         0                                                NaN
# 127632         0                                                NaN
# 296772         0                                                NaN
# 418336         1  USA TODAY\n\nWhen we saw a barely dressed Jess...
#
# [3333 rows x 10 columns]

# %%
for row, url in tzip(newsData_3.index, newsData_3.URL):
    url_new = 'https'+url[4:]
#     print(row, url)
    try:
        article = Article(url_new)
        article.download()
        article.parse()
        newsData_3.loc[row, 'text'] = article.text
        if article.text:
            newsData_3.loc[row, 'got_text'] = 1 
    except: pass
    
newsData_3
# Out:
#   0%|          | 0/3334 [00:00<?, ?it/s]
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/shih-chima/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#             ID                                              TITLE  \
# 316781  317241  GDP: Final Estimate For First Quarter Is Much ...
# 184823  185159            OECD: Clouds hang over emerging markets
# 307351  307811                         HERE COMES FLASH US PMI...
# 376990  377450  Whiting's $6B Deal for Kodiak Would Form Large...
# 101518  101715  Agostini: Colin Kaepernick's mistake is leavin...
# ...        ...                                                ...
# 124304  124640  AG Issues Warning About Wedding Planning Services
# 28960    28961     IRS Watchdog: Impostor Phone Scam Largest Ever
# 223591  224037  Vodafone earnings tumble after 'mixed' perform...
# 400680  401199  NLRB's New Ruling Could Mean Great Things for ...
# 356327  356787                       Dog torched in Numsa rampage
#
#                                                       URL  \
# 316781  http://www.forbes.com/sites/mikepatton/2014/06...
# 184823  http://www.iol.co.za/business/international/oe...
# 307351  http://www.businessinsider.in/HERE-COMES-FLASH...
# 376990  http://www.naturalgasintel.com/articles/99004-...
# 101518  http://www.modbee.com/2014/04/11/3288692/agost...
# ...                                                   ...
# 124304  http://www.northcountrygazette.org/2014/04/15/...
# 28960   http://blog.aarp.org/2014/03/21/irs-watchdog-i...
# 223591  http://www.scotsman.com/business/media-tech-le...
# 400680  http://inthesetimes.com/working/entry/17015/fi...
# 356327  http://www.iol.co.za/the-star/dog-torched-in-n...
#
#                        PUBLISHER CATEGORY                Alphanumeric ID  \
# 316781                    Forbes        b  dDkTxCFNrRmzqyMPP9l7fynC7yuiM
# 184823        Independent Online        b  djYdAphw5jDBdqMzI96Ssguo2rdAM
# 307351     Businessinsider India        b  d7ciPlHSS0FPGHM1D-xxX_18nfo-M
# 376990  Natural Gas Intelligence        b  dap7TgQqIJKCXtMuS6rCqs8qAoRkM
# 101518               Modesto Bee        b  dq4CkE5dd_NRkmMCBHHuQlgb-upoM
# ...                          ...      ...                            ...
# 124304     North Country Gazette        b  d4R99H_bzn5317MgwOcNIUW8-ppSM
# 28960         AARP News \(blog\)        b  dR39a35kcuso-9M3bXDszPvdbxY1M
# 223591                  Scotsman        b  d5U_wamCIMERFaMINjAWXKgW9PJcM
# 400680            In These Times        b  dVHK1NwbYZuSB-MZayQWVGdNouSYM
# 356327        Independent Online        b  dH5WbQom61WDYjMihBLT6FDE49zEM
#
#                        HOSTNAME Url      TIMESTAMP  got_text  \
# 316781               www.forbes.com  1403773543378         0
# 184823                www.iol.co.za  1399437419419         0
# 307351       www.businessinsider.in  1403539558316         1
# 376990      www.naturalgasintel.com  1405425429789         1
# 101518               www.modbee.com  1397290663256         0
# ...                             ...            ...       ...
# 124304  www.northcountrygazette.org  1397702580253         0
# 28960                 blog.aarp.org  1395503779820         0
# 223591             www.scotsman.com  1400581852375         0
# 400680             inthesetimes.com  1406778000166         0
# 356327                www.iol.co.za  1404518804140         0
#
#                                                      text
# 316781                                                NaN
# 184823                                                NaN
# 307351  At 9:45 a.m. ET, Markit will publish the preli...
# 376990  In a move that did not appear to surprise anal...
# 101518                                                NaN
# ...                                                   ...
# 124304                                                NaN
# 28960                                                 NaN
# 223591                                                NaN
# 400680                                                NaN
# 356327                                                NaN
#
# [3334 rows x 10 columns]

# %%
newsData_new = newsData_1.append([newsData_2,newsData_3])

newsData_new = newsData_new[newsData_new.got_text==1]
newsData_new
# Out:
#             ID                                              TITLE  \
# 44056    44057  Missing Malayasia Airlines MH370: China sends ...
# 367142  367602            ECB's Draghi's Plan May Miss the Target
# 47630    47631  Candy Crush Saga shares dive 10% in Wall Stree...
# 41832    41833           Why excessive executive pay is a mistake
# 66042    66043                       CBS Outdoor to Start Trading
# ...        ...                                                ...
# 259019  259465  Presidents of Russia and France to discuss Ukr...
# 301526  301986  Adobe's 2014 Creative Cloud update: Desktop up...
# 51636    51637  Here's Where To Download Microsoft Office For ...
# 333659  334119    Housing Update: Pending Home Sales Surge In May
# 60257    60258  Wal-Mart Sues Visa for $5 Billion for Fixing a...
#
#                                                       URL  \
# 44056   http://www.india.com/loudspeaker/missing-malay...
# 367142  http://www.marketpulse.com/20140706/ecbs-dragh...
# 47630   http://www.thisismoney.co.uk/money/markets/art...
# 41832   http://www.cbsnews.com/news/why-excessive-exec...
# 66042   http://www.nasdaq.com/article/cbs-outdoor-to-s...
# ...                                                   ...
# 259019  http://www.theguardian.com/world/2014/may/28/v...
# 301526  http://www.zdnet.com/adobes-2014-creative-clou...
# 51636   http://www.businessinsider.in/Heres-Where-To-D...
# 333659  http://www.benzinga.com/news/14/06/4670897/hou...
# 60257   http://www.thestreet.com/story/12559013/1/wal-...
#
#                     PUBLISHER CATEGORY                Alphanumeric ID  \
# 44056               India.com        b  dpJ38zm8NY8hUFM22x2aL0hc9hjfM
# 367142   MarketPulse \(blog\)        b  dybB1-1U7xt8vLMLKhbW1GpBlkggM
# 47630           This is Money        b  dQtK6MP92Wshd3MbmOLp71BNJ1smM
# 41832                CBS News        b  dCT-PMJKDpxizFM1KG4HNznXSzt9M
# 66042                  NASDAQ        b  dUzQIN3A2UMV7cM7WXmdwd290P7pM
# ...                       ...      ...                            ...
# 259019           The Guardian        b  dCXZzr8rVI5aTGMgAB8jJXCTtcnGM
# 301526                  ZDNet        b  dx5rs7ln2b_Ad8MMGjFrLWi0Q-R6M
# 51636   Businessinsider India        b  dUlKgaqxUngrA5MKtr_8lQs0ElRzM
# 333659               Benzinga        b  d_gSOVyb6AktUYMCiBrZgMdhpbkTM
# 60257           TheStreet.com        b  dKwfGmHtx83tlFMihMrrm2217IbOM
#
#                   HOSTNAME Url      TIMESTAMP  got_text  \
# 44056            www.india.com  1395824966103         1
# 367142     www.marketpulse.com  1404822872146         1
# 47630    www.thisismoney.co.uk  1395880982244         1
# 41832          www.cbsnews.com  1395772526278         1
# 66042           www.nasdaq.com  1396177634518         1
# ...                        ...            ...       ...
# 259019     www.theguardian.com  1401288128176         1
# 301526           www.zdnet.com  1403115969825         1
# 51636   www.businessinsider.in  1395951444425         1
# 333659        www.benzinga.com  1404144616697         1
# 60257        www.thestreet.com  1396067257757         1
#
#                                                      text
# 44056   Also Read - Australia: Memorial Planned Honour...
# 367142  Mario Draghi’s plan to end the euro area’s len...
# 47630   Candy Crush Saga shares dive 10% in Wall Stree...
# 41832   Commentary:\n\nWhen David Winters, a longtime ...
# 66042   Your symbols have been updated\n\nYou'll now b...
# ...                                                   ...
# 259019  The Russian president, Vladimir Putin, will di...
# 301526  Adobe's Creative Cloud (CC), the subscription-...
# 51636   Microsoft launched Office for iPad today, maki...
# 333659  The National Association of Realtors reports t...
# 60257   NEW YORK (TheStreet) -- Wal-Mart is suing Visa...
#
# [4133 rows x 10 columns]

# %%
newsData_new.to_csv('news_data.csv')

# %%
newsData_new[newsData_new.ID==322309]
# Out:
#             ID                                      TITLE  \
# 321849  322309  May consumer spending up modestly at 0.2%
#
#                                                       URL  \
# 321849  http://www.businesstimes.com.sg/premium/world/...
#
#                                   PUBLISHER CATEGORY  \
# 321849  THE BUSINESS TIMES \(subscription\)        b
#
#                       Alphanumeric ID              HOSTNAME Url  \
# 321849  dcnLpLtxYqnLt9MRM43DAw7DaNy2M  www.businesstimes.com.sg
#
#             TIMESTAMP  got_text text
# 321849  1403852150072         0
